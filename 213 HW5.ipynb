# %%
import pandas as pd
# %matplotlib inline
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from sklearn import datasets

#from sklearn.datasets import fetch_mldata

# %%
mnist = datasets.load_digits()
x = mnist.data
y = mnist.target

print(x.shape)
# Out:
# (1797, 64)

# %%
from sklearn.decomposition import PCA

# %%
#1. PCA
pca = PCA()
x_pca = pca.fit_transform(x)
cum_ratio = np.cumsum(pca.explained_variance_ratio_)

f, ax = plt.subplots(figsize=(8,6))
plt.plot(range(len(cum_ratio)), cum_ratio)
plt.ylabel('Explained Variance')
plt.xlabel('Components')

#A. Using 18 components as this is where the elbow coordinate lies. The variance will begin to decrease after this point so this
# seemed appropriate.
# Out:
# Text(0.5, 0, 'Components')

# %%
pca = PCA(n_components = 18)
data_pca = pca.fit_transform(x)

f, ax = plt.subplots(figsize = (9,7))
plt.scatter(data_pca[:, 0], data_pca[:, 1],
            c=y, edgecolor='none', alpha=0.5)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title('Principle Components 1&2')
# Out:
# Text(0.5, 1.0, 'Principle Components 1&2')

# %% [raw]
# B. The graph shows the purple the purple points distributed around the top or the bottom of the graph in condensed groups.
#  The other color points don't necessarily follow a pattern and seem scattered all over the place.
#
#  C. PCA is used to reduce dimensionality in the data. It accomplishes this by dropping the the axes with the lowest variance.
#  In this particular model, this might not really be necessary to use.
#  For models like KNN it would be helpful since dimensionality can ruin a KNN model.
#  In general, most models and algorithms don't need reduced dimensionality.

# %% [raw]
# 2. TSNE

# %%
from sklearn.manifold import TSNE

pca = PCA(n_components=50)
x_pca = pca.fit_transform(x)

rows = np.arange(1797)
np.random.shuffle(rows)
n_select = 10000

tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=1000, learning_rate=200)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.010s...
# [t-SNE] Computed neighbors for 1797 samples in 0.673s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 8.639315
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 61.625313
# [t-SNE] KL divergence after 1000 iterations: 0.685086

# %%
df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]
sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)

# %% [raw]
#  The plot clusters are distribued more tightly than those of PCA. Each cluster can be visualized separately.

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=10, n_iter=1000, learning_rate=200)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.006s...
# [t-SNE] Computed neighbors for 1797 samples in 0.410s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 6.719963
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.882706
# [t-SNE] KL divergence after 1000 iterations: 0.888811

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=5, n_iter=1000, learning_rate=200)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.008s...
# [t-SNE] Computed neighbors for 1797 samples in 0.410s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 5.706739
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.580551
# [t-SNE] KL divergence after 1000 iterations: 0.930151

# %% [raw]
#  Reduced perplexitiy here to group and separate the clusters even further and appear less clumped.

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=5, n_iter=300, learning_rate=200)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.006s...
# [t-SNE] Computed neighbors for 1797 samples in 0.432s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 5.706739
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.334480
# [t-SNE] KL divergence after 300 iterations: 1.795737

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=5, n_iter=1000, learning_rate=10)
tsne_results = tsne.fit_transform(x_pca[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = y[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.007s...
# [t-SNE] Computed neighbors for 1797 samples in 0.378s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 5.706739
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 73.027084
# [t-SNE] KL divergence after 1000 iterations: 1.066986

# %% [raw]
#  C. Changing the learning rate levels from 200 to 10 didn't show too many differences in results
#  Model seems quite robust

# %% [raw]
#  3. K-Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(n_clusters=10, n_init=50)
kmeans.fit(x)
labels = kmeans.labels_
silhouette_score(x, labels, metric='euclidean')
# Out:
# 0.18233161339350462

# %% [raw]
#  A. Used 10 as the value for K. Recommended value was between 1 and 10.
#
#  B. Used Silhouette Score to evaluate my model.
#  The coefficient is the mean distance between a sample and all other points in the next nearest cluster
#  subtracted by the mean distance between a sample and all other points in the same class.
#
#  C. Below

# %%
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=1000, learning_rate=50)
tsne_results = tsne.fit_transform(x[rows[:n_select],:])

df_tsne = pd.DataFrame(tsne_results, columns=['component 1', 'component 2'])
df_tsne['label'] = labels[rows[:n_select]]

sns.lmplot(x='component 1', y='component 2', data=df_tsne, hue='label', palette = 'RdBu', fit_reg=False)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1797 samples in 0.010s...
# [t-SNE] Computed neighbors for 1797 samples in 0.566s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1797
# [t-SNE] Computed conditional probabilities for sample 1797 / 1797
# [t-SNE] Mean sigma: 8.121139
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 61.782665
# [t-SNE] KL divergence after 1000 iterations: 0.762145

# %% [raw]
#  D. Data was not scaled
#
#  E. Data looks relatively robust. The groups have majority coloring, but still has some color mixtures in the clusters.

# %% [raw]
#  4. Hierarchical Clustering

# %%
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
x_cluster = x[:100]

# %%
# A. Dendrogram:
Z = linkage(x_cluster, 'complete')
plt.figure(figsize=(15, 12))
_ = dendrogram(Z)

# %%
# There are about 10 clusters when using 0.5 on the y-axis

# %%
Z = linkage(x_cluster, 'average')
plt.figure(figsize=(15, 12))
_ = dendrogram(Z)

# %% [raw]
#  C. The different linkage method made more clusters compared to the other on average
#  'Complete' makes connections earlier than 'average' did.
